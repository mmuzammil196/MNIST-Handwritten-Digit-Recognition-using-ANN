# %% [markdown]
# ### **✍️🔢 Hand Written Digit Classification Using ANN - Multi Classification Problem**

# %% [markdown]
# ![MNIST Handwritten Digit Recognition using ANN.jpg](attachment:f6384008-930b-45c0-85d2-e76a0141ea96.jpg)

# %% [markdown]
# # **Importing the Libraries**

# %%
# libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %% [markdown]
# # **Download the Dataset from Keras Library**

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %% [markdown]
# # **Explore the Dataset**

# %%
# shape of X_train dataset
X_train.shape
# Out:
# (60000, 28, 28)

# %%
# shape of X_test dataset
X_test.shape
# Out:
# (10000, 28, 28)

# %%
# shape of y_train dataset
y_train.shape
# Out:
# (60000,)

# %%
# shape of y_test dataset
y_test.shape
# Out:
# (10000,)

# %% [markdown]
# # **Standarize the X_train & X_test Data in range between 0 & 1**

# %%
X_train = X_train / 255
X_test = X_test / 255

# %% [markdown]
# # **Target Feature Check and Plot Digits Images**

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
y_test
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
plt.imshow(X_train[0])

# %%
plt.imshow(X_train[1])

# %%
plt.imshow(X_train[2])

# %% [markdown]
# # **Model Building - Train the Model**

# %%
model = Sequential()

model.add(Flatten(input_shape=(28, 28)))
# input nodes
model.add(Dense(128, activation = 'relu'))
# output nodes and use softmax for multi classification problem
model.add(Dense(10, activation = 'softmax'))

# %%
# model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 128)               100480
#
#  dense_5 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compilation of model. use sparse categorical cross entropy for not apply one hot encoding when using this method
model.compile(loss='sparse_categorical_crossentropy', optimizer = 'Adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs = 10, validation_split = 0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2913 - accuracy: 0.9173 - val_loss: 0.1666 - val_accuracy: 0.9498
# Epoch 2/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1310 - accuracy: 0.9619 - val_loss: 0.1271 - val_accuracy: 0.9623
# Epoch 3/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0881 - accuracy: 0.9743 - val_loss: 0.0983 - val_accuracy: 0.9695
# Epoch 4/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0663 - accuracy: 0.9806 - val_loss: 0.0922 - val_accuracy: 0.9708
# Epoch 5/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0513 - accuracy: 0.9849 - val_loss: 0.0937 - val_accuracy: 0.9722
# Epoch 6/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0408 - accuracy: 0.9878 - val_loss: 0.0929 - val_accuracy: 0.9730
# Epoch 7/10
# ...

# %% [markdown]
# # **Visualize the Loss of Both Train and Test**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %% [markdown]
# # **Visualize the Accuracy of Both Train and Test**

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %% [markdown]
# # **Model - Prediction**

# %%
y_prob = model.predict(X_test)
y_pred = y_prob.argmax(axis = 1)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
# model predict digit 7 of x_test data
y_pred[0]
# Out:
# 7

# %% [markdown]
# # **Visualize the Prediction Digit Image**

# %%
plt.imshow(X_test[0])

# %% [markdown]
# # **Model - Accuracy - Check**

# %%
# accuracy of model is 97 %
accuracy_score(y_test, y_pred)
# Out:
# 0.9769

# %% [markdown]
# # **Thanks for Visiting My Notebook**
